# %%
import numpy as np
import pandas as pd
df=pd.read_csv(r"C:\Users\ARSHAD MALIK\Contacts\file.csv")
df
# Out:
#          day  chicago  chennai  berlin
# 0     Monday     32.0       75    41.0
# 1    Tuesday     30.0       77     NaN
# 2  Wednesday      NaN       75    45.0
# 3   Thursday     22.0       82    38.0
# 4     Friday     30.0       83    30.0
# 5   Saturday     20.0       81     NaN
# 6     Sunday      NaN       77    47.0

# %%
df.isna().sum()
# Out:
# day        0
# chicago    2
# chennai    0
# berlin     2
# dtype: int64

# %%
newdf=df.fillna(0)

# %%
newdf
# Out:
#          day  chicago  chennai  berlin
# 0     Monday     32.0       75    41.0
# 1    Tuesday     30.0       77     0.0
# 2  Wednesday      0.0       75    45.0
# 3   Thursday     22.0       82    38.0
# 4     Friday     30.0       83    30.0
# 5   Saturday     20.0       81     0.0
# 6     Sunday      0.0       77    47.0

# %%
newdf1=df.fillna({
"chicago":10000,
"berlin":"fillurself"})
newdf1
# Out:
#          day  chicago  chennai      berlin
# 0     Monday     32.0       75        41.0
# 1    Tuesday     30.0       77  fillurself
# 2  Wednesday  10000.0       75        45.0
# 3   Thursday     22.0       82        38.0
# 4     Friday     30.0       83        30.0
# 5   Saturday     20.0       81  fillurself
# 6     Sunday  10000.0       77        47.0

# %%
ndf=df.interpolate(method="quadratic")
ndf
# Out:
#          day    chicago  chennai     berlin
# 0     Monday  32.000000       75  41.000000
# 1    Tuesday  30.000000       77  46.167614
# 2  Wednesday  23.567568       75  45.000000
# 3   Thursday  22.000000       82  38.000000
# 4     Friday  30.000000       83  30.000000
# 5   Saturday  20.000000       81  32.394886
# 6     Sunday        NaN       77  47.000000

# %%
ndf.columns
# Out:
# Index(['day', 'chicago', 'chennai', 'berlin'], dtype='object')

# %%
ndf.columns=[x.upper() for x in ndf.columns]

# %%
ndf
# Out:
#          DAY    CHICAGO  CHENNAI     BERLIN
# 0     Monday  32.000000       75  41.000000
# 1    Tuesday  30.000000       77  46.167614
# 2  Wednesday  23.567568       75  45.000000
# 3   Thursday  22.000000       82  38.000000
# 4     Friday  30.000000       83  30.000000
# 5   Saturday  20.000000       81  32.394886
# 6     Sunday        NaN       77  47.000000

# %%
ndf.rename(columns={"DAY":"daaaay","BERLIN":"uK"},inplace=True)

# %%
ndf
# Out:
#       daaaay    CHICAGO  CHENNAI         uK
# 0     Monday  32.000000       75  41.000000
# 1    Tuesday  30.000000       77  46.167614
# 2  Wednesday  23.567568       75  45.000000
# 3   Thursday  22.000000       82  38.000000
# 4     Friday  30.000000       83  30.000000
# 5   Saturday  20.000000       81  32.394886
# 6     Sunday        NaN       77  47.000000

# %%
ndf['uK']=ndf['uK'].replace({46.167614:46.0000})

# %%
ndf
# Out:
#       daaaay    CHICAGO  CHENNAI         uK
# 0     Monday  32.000000       75  41.000000
# 1    Tuesday  30.000000       77  46.167614
# 2  Wednesday  23.567568       75  45.000000
# 3   Thursday  22.000000       82  38.000000
# 4     Friday  30.000000       83  30.000000
# 5   Saturday  20.000000       81  32.394886
# 6     Sunday        NaN       77  47.000000

# %%
def ct(CHENNAI):
    return CHENNAI/10

# %%
ndf
# Out:
#       daaaay    CHICAGO  CHENNAI         uK
# 0     Monday  32.000000       75  41.000000
# 1    Tuesday  30.000000       77  46.167614
# 2  Wednesday  23.567568       75  45.000000
# 3   Thursday  22.000000       82  38.000000
# 4     Friday  30.000000       83  30.000000
# 5   Saturday  20.000000       81  32.394886
# 6     Sunday        NaN       77  47.000000

# %%
ndf['CHENNAI']=ndf['CHENNAI'].apply(ct)

# %%
ndf
# Out:
#       daaaay    CHICAGO  CHENNAI         uK
# 0     Monday  32.000000      7.5  41.000000
# 1    Tuesday  30.000000      7.7  46.167614
# 2  Wednesday  23.567568      7.5  45.000000
# 3   Thursday  22.000000      8.2  38.000000
# 4     Friday  30.000000      8.3  30.000000
# 5   Saturday  20.000000      8.1  32.394886
# 6     Sunday        NaN      7.7  47.000000

# %%
ndf['CHENNAI'].apply(lambda x:x*100)
# Out:
# 0    750.0
# 1    770.0
# 2    750.0
# 3    820.0
# 4    830.0
# 5    810.0
# 6    770.0
# Name: CHENNAI, dtype: float64

# %%
ndf['CHENNAI']=ndf['CHENNAI'].apply(lambda x:x*100)

# %%
ndf
# Out:
#       daaaay    CHICAGO  CHENNAI         uK
# 0     Monday  32.000000    750.0  41.000000
# 1    Tuesday  30.000000    770.0  46.167614
# 2  Wednesday  23.567568    750.0  45.000000
# 3   Thursday  22.000000    820.0  38.000000
# 4     Friday  30.000000    830.0  30.000000
# 5   Saturday  20.000000    810.0  32.394886
# 6     Sunday        NaN    770.0  47.000000

# %%
event=['s','w','snow','h','hot','r','dry']

# %%
ndf['events']=event

# %%
ndf
# Out:
#       daaaay    CHICAGO  CHENNAI         uK events
# 0     Monday  32.000000    750.0  41.000000      s
# 1    Tuesday  30.000000    770.0  46.167614      w
# 2  Wednesday  23.567568    750.0  45.000000   snow
# 3   Thursday  22.000000    820.0  38.000000      h
# 4     Friday  30.000000    830.0  30.000000    hot
# 5   Saturday  20.000000    810.0  32.394886      r
# 6     Sunday        NaN    770.0  47.000000    dry

# %%
ndf.drop(["events"],axis=1,inplace=True)

# %%
ndf
# Out:
#       daaaay    CHICAGO  CHENNAI         uK
# 0     Monday  32.000000    750.0  41.000000
# 1    Tuesday  30.000000    770.0  46.167614
# 2  Wednesday  23.567568    750.0  45.000000
# 3   Thursday  22.000000    820.0  38.000000
# 4     Friday  30.000000    830.0  30.000000
# 5   Saturday  20.000000    810.0  32.394886
# 6     Sunday        NaN    770.0  47.000000

# %%
ndf=ndf.append({'daaaay':'january','uK':7500},ignore_index=True)

# %%
ndf
# Out:
#       daaaay    CHICAGO  CHENNAI           uK
# 0     Monday  32.000000    750.0    41.000000
# 1    Tuesday  30.000000    770.0    46.167614
# 2  Wednesday  23.567568    750.0    45.000000
# 3   Thursday  22.000000    820.0    38.000000
# 4     Friday  30.000000    830.0    30.000000
# 5   Saturday  20.000000    810.0    32.394886
# 6     Sunday        NaN    770.0    47.000000
# 7    january        NaN      NaN  7500.000000

# %%
ndf.drop(index=7)
# Out:
#       daaaay    CHICAGO  CHENNAI         uK
# 0     Monday  32.000000    750.0  41.000000
# 1    Tuesday  30.000000    770.0  46.167614
# 2  Wednesday  23.567568    750.0  45.000000
# 3   Thursday  22.000000    820.0  38.000000
# 4     Friday  30.000000    830.0  30.000000
# 5   Saturday  20.000000    810.0  32.394886
# 6     Sunday        NaN    770.0  47.000000
